-- %%
SELECT * FROM sales_project_db.bronze_sales;

-- %%
describe sales_project_db.bronze_sales;

-- %%
select count(*),count(distinct(Row_ID)) from sales_project_db.bronze_sales;

-- %%
select count(*),count(distinct(Product_ID)),count(distinct(Order_ID)) from sales_project_db.bronze_sales;

-- %%
SELECT count(Order_ID,Product_ID),count(distinct(Order_ID,Product_ID)) FROM sales_project_db.bronze_sales;

-- %%
SELECT * from sales_project_db.bronze_sales where(Order_ID,Product_ID) in (SELECT Order_ID,Product_ID FROM sales_project_db.bronze_sales group by Order_ID,Product_ID having count(*)>1);

-- %%
SELECT * from sales_project_db.bronze_sales where(Order_ID,Product_ID,Customer_ID) in (SELECT Order_ID,Product_ID,Customer_ID FROM sales_project_db.bronze_sales group by Order_ID,Product_ID,Customer_ID having count(*)>1);

-- %%
select count(distinct(Country)) from sales_project_db.bronze_sales;
